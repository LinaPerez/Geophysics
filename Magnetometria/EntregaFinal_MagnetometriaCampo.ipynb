# %% [markdown]
# # Magnetometria

# %% [markdown]
# ###### por: Lina Pérez Ángel

# %% [markdown]
# En este archivo se realizará las gráficas e interpretaciones de los datos de Magnetometría tomados en Campo durante la semana del 20 al 27 de Septiembre del 2014. Este campo fué realizado entre Mariquita - Armero-Guayabal - Armero Viejo - Piedras en el departamento del Tolima.

# %%
# %pylab inline  
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Grupo I

# %%
datos1 = loadtxt("DatosCampo/Grupo_I_X.txt")
x1 = datos1[:,0]
y1 = datos1[:,1]
teslas1 = datos1[:,2]

# %%
datos2 = loadtxt("DatosCampo/Grupo_I_Y.txt")
x2 = datos2[:,0]
y2 = datos2[:,1]
teslas2 = datos2[:,2]

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(x1, y1, s=10, c='b')
ax1.scatter(x2,y2, s=10, c='g')
plt.title("Rejilla de los Datos tomados en campo")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.show()
