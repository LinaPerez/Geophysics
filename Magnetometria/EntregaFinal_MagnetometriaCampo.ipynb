# %% [markdown]
# # Magnetometria

# %% [markdown]
# ###### por: Lina Pérez Ángel

# %% [markdown]
# En este archivo se realizará las gráficas e interpretaciones de los datos de Magnetometría tomados en Campo durante la semana del 20 al 27 de Septiembre del 2014. Este campo fué realizado entre Mariquita - Armero-Guayabal - Armero Viejo - Piedras en el departamento del Tolima.

# %%
# %pylab inline  
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import matplotlib.tri as mtri
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Grupo I

# %%
datos1 = loadtxt("DatosCampo/Grupo_I_X.txt")
x1 = datos1[:,0]
y1 = datos1[:,1]
teslas1 = datos1[:,2]

# %%
datos2 = loadtxt("DatosCampo/Grupo_I_Y.txt")
x2 = datos2[:,0]
y2 = datos2[:,1]
teslas2 = datos2[:,2]

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(x1, y1, s=10, c='b')
ax1.scatter(x2,y2, s=10, c='g')
plt.title("Rejilla de los Datos tomados en campo")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.show()

# %%
datostodos=loadtxt("DatosCampo/completo_I.txt", usecols = (0,1,2))
X = datostodos[:,0]
Y = datostodos[:,1]
Z = datostodos[:,2]

# %%
fig = plt.figure(figsize=(16,8))
ax = fig.gca(projection='3d')
p=Axes3D.plot(X,Y,Z, cmap=cm.jet, linewidth=0.2)
c2 = fig.colorbar(p)
ax.set_xlabel(r'Eje X', fontsize=20)
ax.set_ylabel(r'Eje Y', fontsize=20)
ax.set_zlabel(r'nanoTeslas (nT)', fontsize=20)
ax.set_title(r'Anomalia magnetica ',fontsize=25)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-573328260b4c> in <module>()
#       1 fig = plt.figure(figsize=(16,8))
#       2 ax = fig.gca(projection='3d')
# ----> 3 p=Axes3D.plot(X,Y,Z, cmap=cm.jet, linewidth=0.2)
#       4 c2 = fig.colorbar(p)
#       5 ax.set_xlabel(r'Eje X', fontsize=20)
#
# TypeError: unbound method plot() must be called with Axes3D instance as first argument (got ndarray instance instead)

# %%
fig = plt.figure(figsize=(8,6))

ax = fig.add_subplot(1,1,1, projection='3d')

ax.plot(X, Y, Z,  alpha=0.25)
#cset = ax.contour(X, Y, Z, zdir='z', offset=-pi, cmap=cm.coolwarm)
#cset = ax.contour(X, Y, Z, zdir='x', offset=-pi, cmap=cm.coolwarm)
#cset = ax.contour(X, Y, Z, zdir='y', offset=3*pi, cmap=cm.coolwarm)

#ax.set_xlim3d(-pi, 2*pi);
#ax.set_ylim3d(0, 3*pi);
#ax.set_zlim3d(-pi, 2*pi);

# %% [markdown]
# ###
