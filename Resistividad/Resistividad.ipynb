# %% [markdown]
# # Resistividad

# %%
# %pylab inline
import matplotlib.pyplot as plt
import Image
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Grupo A

# %% [markdown]
# #### Linea 1

# %%
L_1 = 60

datos1 = np.loadtxt('linea1_grupoA.txt')

# %%
I_1 = datos1[:,0]
V_1 = datos1[:,1]
l_1 = datos1[:,2]

# %%
for i in range (len(I_1)):
    res_a = pi*(((L_1**2)-(l_1**2))**2)
    res_b = 2*l_1*((L_1**2)-(l_1**2))
    res_c = (absolute(V_1[5] - V_1[0] ) / I_1[i])
    resistividad_1 = (res_a / res_b)*res_c
    plot (l_1, resistividad_1)
    scatter (l_1, resistividad_1)
    plt.title('Linea 1 Grupo A')
    plt.xlabel('l (distancia)')
    plt.ylabel('Resistividad')

# %% [markdown]
# #### Linea 2

# %%
l_2 = 2
datos2 = np.loadtxt('LInea2_GrupoA.txt')
I_2 = datos2[:,0]
V_2 = datos2[:,1]
L_2 = datos2[:,2]

# %%
for i in range (len(I_2)):
    res_a2 = pi*(L_2**2)
    res_b2 = 2*l_2
    res_c2 = (absolute(V_2[2] - V_2[0] ) / I_2[i])
    resistividad_2 = (res_a2 / res_b2)*res_c2
    scatter (L_2, resistividad_2)
    plot(L_2, resistividad_2)
    plt.title('Linea 2 Grupo A')
    plt.xlabel('L (distancia)')
    plt.ylabel('Resistividad')

# %% [markdown]
# #### Linea 3

# %%
l_3 = 2
datos3 = np.loadtxt('Linea3_GrupoA.txt')
I_3 = datos3[:,0]
V_3 = datos3[:,1]
L_3 = datos3[:,2]

# %%
for i in range (len(I_3)):
    res_a3 = pi*(L_3**2)
    res_b3 = 2*l_3
    res_c3 = (absolute(V_3[23] - V_3[0] ) / I_3[i])
    resistividad_3 = (res_a3 / res_b3)*res_c3
    scatter (L_3, resistividad_3)
    plot(L_3, resistividad_3)
    plt.title('Linea 3 Grupo A')
    plt.xlabel('L (distancia)')
    plt.ylabel('Resistividad')

# %% [markdown]
# #### Linea 4

# %%
L_4 = 50
datos4 = np.loadtxt('Linea4_GrupoA.txt')
I_4 = datos4[:,0]
V_4 = datos4[:,1]
l_4 = datos4[:,2]
print size(V_4[:])
# Out:
# 11

# %%
for i in range (len(I_4)):
    res_a4 = pi*(((L_4**2)-(l_4**2))**2)
    res_b4 = 2*l_4*((L_4**2)-(l_4**2))
    res_c4 = (absolute(V_4[10] - V_4[0] ) / I_4[i])
    resistividad_4 = (res_a4 / res_b4)*res_c4
    plot (l_4, resistividad_4)
    scatter (l_4, resistividad_4)
    plt.title('Linea 4 Grupo A')
    plt.xlabel('l (distancia)')
    plt.ylabel('Resistividad')

# %% [markdown]
# ## Grupo Diaz-Garzón

# %%
L_5 = 30
datos5 = np.loadtxt('grupo_GarzonDiazCortes.txt')
I_5 = datos5[:,0]
V_5 = datos5[:,1]
Vo_5 = datos5[:,2]
l_5 = datos5[:,3]

# %%
for i in range (len(I_5)):
    res_a5 = pi*(((L_5**2)-(l_5**2))**2)
    res_b5 = 2*l_5*((L_5**2)-(l_5**2))
    res_c5 = (absolute(V_5[i] - Vo_5[i] ) / I_5[i])
    resistividad_5 = (res_a5 / res_b5)*res_c5
    plot (l_5, resistividad_5)
    scatter (l_5, resistividad_5)
    plt.title('Linea 1 Grupo Garzon-Diaz-Cortes')
    plt.xlabel('l (distancia)')
    plt.ylabel('Resistividad')

# %% [markdown]
# ## Grupo I

# %% [markdown]
# #### Linea 1

# %%
L_6 = 15
datos6 = np.loadtxt('GrupoI_linea1.txt')
I_6 = datos6[:,0]
V_6 = datos6[:,2]
Vo_6 = datos6[:,1]
l_6 = datos6[:,3]

for i in range (len(I_6)):
    res_a6 = pi*(((L_6**2)-(l_6**2))**2)
    res_b6 = 2*l_6*((L_6**2)-(l_6**2))
    res_c6 = (absolute(V_6[i] - Vo_6[i] ) / I_6[i])
    resistividad_6 = (res_a6 / res_b6)*res_c6
    plot (l_6, resistividad_6)
    scatter (l_6, resistividad_6)
    plt.title('Linea 1 Grupo I')
    plt.xlabel('l (distancia)')
    plt.ylabel('Resistividad')

# %% [markdown]
# #### Linea 1_b

# %%
L_7 = 15
datos7 = np.loadtxt('GrupoI_linea1_b.txt')
I_7 = datos7[:,0]
V_7 = datos7[:,2]
Vo_7 = datos7[:,1]
l_7 = datos7[:,3]

for i in range (len(I_7)):
    res_a7 = pi*(((L_7**2)-(l_7**2))**2)
    res_b7 = 2*l_7*((L_7**2)-(l_7**2))
    res_c7 = (absolute(V_7[i] - Vo_7[i] ) / I_7[i])
    resistividad_7 = (res_a7 / res_b7)*res_c7
    plot (l_7, resistividad_7)
    scatter (l_7, resistividad_7)
    plt.title('Linea 1_b Grupo I')
    plt.xlabel('l (distancia)')
    plt.ylabel('Resistividad')

# %%
L_8 = 15
datos8 = np.loadtxt('GrupoI_linea2.txt')
I_8 = datos8[:,0]
V_8 = datos8[:,2]
Vo_8 = datos8[:,1]
l_8 = datos8[:,3]

for i in range (len(I_8)):
    res_a8 = pi*(((L_8**2)-(l_8**2))**2)
    res_b8 = 2*l_8*((L_8**2)-(l_8**2))
    res_c8 = (absolute(V_8[i] - Vo_8[i] ) / I_8[i])
    resistividad_8 = (res_a8 / res_b8)*res_c8
    plot (l_8, resistividad_8)
    scatter (l_8, resistividad_8)
    plt.title('Linea 2 Grupo I')
    plt.xlabel('l (distancia)')
    plt.ylabel('Resistividad')

# %%
L_9 = 15
datos9 = np.loadtxt('GrupoI_linea2_b.txt')
I_9 = datos9[:,0]
V_9 = datos9[:,2]
Vo_9 = datos9[:,1]
l_9= datos9[:,3]

for i in range (len(I_9)):
    res_a9 = pi*(((L_9**2)-(l_9**2))**2)
    res_b9 = 2*l_9*((L_9**2)-(l_9**2))
    res_c9 = (absolute(V_9[i] - Vo_9[i] ) / I_9[i])
    resistividad_9 = (res_a9 / res_b9)*res_c9
    plot (l_9, resistividad_9)
    scatter (l_9, resistividad_9)
    plt.title('Linea 2_b Grupo I')
    plt.xlabel('l (distancia)')
    plt.ylabel('Resistividad')

# %%
L_9b = 15
datos9b = np.loadtxt('GrupoI_linea3.txt')
I_9b = datos9b[:,0]
V_9b = datos9b[:,2]
Vo_9b = datos9b[:,1]
l_9b= datos9b[:,3]

for i in range (len(I_9b)):
    res_a9b = pi*(((L_9b**2)-(l_9b**2))**2)
    res_b9b = 2*l_9b*((L_9b**2)-(l_9b**2))
    res_c9b = (absolute(V_9b[i] - Vo_9b[i] ) / I_9b[i])
    resistividad_9b = (res_a9b / res_b9b)*res_c9b
    plot (l_9b, resistividad_9b)
    scatter (l_9b, resistividad_9b)
    plt.title('Linea 3 Grupo I')
    plt.xlabel('l (distancia)')
    plt.ylabel('Resistividad')

# %%
L_9c = 15
datos9c = np.loadtxt('GrupoI_linea3_b.txt')
I_9c = datos9c[:,0]
V_9c = datos9c[:,2]
Vo_9c = datos9c[:,1]
l_9c= datos9c[:,3]

for i in range (len(I_9c)):
    res_a9c = pi*(((L_9c**2)-(l_9c**2))**2)
    res_b9c = 2*l_9c*((L_9c**2)-(l_9c**2))
    res_c9c = (absolute(V_9c[i] - Vo_9c[i] ) / I_9c[i])
    resistividad_9c = (res_a9c / res_b9c)*res_c9c
    plot (l_9c, resistividad_9c)
    scatter (l_9c, resistividad_9c)
    plt.title('Linea 3_b Grupo I')
    plt.xlabel('l (distancia)')
    plt.ylabel('Resistividad')

# %% [markdown]
# ## Grupo Martes

# %% [markdown]
# #### linea 1

# %%
L_1m = 50

datos1m = np.loadtxt('Grupo_martes_linea1.txt')

# %%
l_1m = datos1m[:,0]
V_1m = datos1m[:,1]
I_1m = datos1m[:,2]

for i in range (len(I_1m)):
    res_am = pi*(((L_1m**2)-(l_1m**2))**2)
    res_bm = 2*l_1m*((L_1m**2)-(l_1m**2))
    res_cm = (absolute(V_1m[47] - V_1m[0] ) / I_1m[i])
    resistividad_1m = (res_am / res_bm)*res_cm
    plot (l_1m, resistividad_1m)
    scatter (l_1m, resistividad_1m)
    plt.title('Linea 1 Grupo martes')
    plt.xlabel('l (distancia)')
    plt.ylabel('Resistividad')

# %% [markdown]
# #### Linea 2

# %%
L_2m = 50

datos2m = np.loadtxt('GrupoMartes_linea2.txt')
l_2m = datos2m[:,0]
V_2m = datos2m[:,1]
I_2m = datos2m[:,2]

for i in range (len(I_2m)):
    res_am2 = pi*(((L_2m**2)-(l_2m**2))**2)
    res_bm2 = 2*l_2m*((L_2m**2)-(l_2m**2))
    res_cm2 = (absolute(V_2m[23] - V_2m[0] ) / I_2m[i])
    resistividad_2m = (res_am2 / res_bm2)*res_cm2
    plot (l_2m, resistividad_2m)
    scatter (l_2m, resistividad_2m)
    plt.title('Linea 2 Grupo martes')
    plt.xlabel('l (distancia)')
    plt.ylabel('Resistividad')

# %% [markdown]
# #### Linea 3

# %%
L_2vm = 50

datos2vm = np.loadtxt('grupomartes_linea3.txt')
l_2vm = datos2vm[:,0]
V_2vm = datos2vm[:,1]
I_2vm = datos2vm[:,2]
print len(V_2vm)
for i in range (len(I_2vm)):
    res_amv2 = pi*(((L_2vm**2)-(l_2vm**2))**2)
    res_bmv2 = 2*l_2vm*((L_2vm**2)-(l_2vm**2))
    res_cmv2 = (absolute(V_2vm[8] - V_2vm[0] ) / I_2vm[i])
    resistividad_2vm = (res_amv2 / res_bmv2)*res_cmv2
    plot (l_2vm, resistividad_2vm)
    scatter (l_2vm, resistividad_2vm)
    plt.title('Linea 3 Grupo martes')
    plt.xlabel('l (distancia)')
    plt.ylabel('Resistividad')
# Out:
# 9

# %% [markdown]
# #### Linea 4

# %%
L_4m = 50

datos4m = np.loadtxt('grupomartes_linea4')
l_4m = datos4m[:,0]
V_4m = datos4m[:,1]
I_4m = datos4m[:,2]

for i in range (len(I_4m)):
    res_am4 = pi*(((L_4m**2)-(l_4m**2))**2)
    res_bm4 = 2*l_4m*((L_4m**2)-(l_4m**2))
    res_cm4= (absolute(V_4m[6] - V_4m[0] ) / I_4m[i])
    resistividad_4m = (res_am4 / res_bm4)*res_cm4
    plot (l_4m, resistividad_4m)
    scatter (l_4m, resistividad_4m)
    plt.title('Linea 4 Grupo martes')
    plt.xlabel('l (distancia)')
    plt.ylabel('Resistividad')

# %% [markdown]
# #### Linea 5

# %%
L_5m = 50

datos5m = np.loadtxt('grupomartes_linea5.txt')
l_5m = datos5m[:,0]
V_5m = datos5m[:,1]
I_5m = datos5m[:,2]
print len(V_5m)
for i in range (len(I_5m)):
    res_am5 = pi*(((L_5m**2)-(l_5m**2))**2)
    res_bm5 = 2*l_5m*((L_5m**2)-(l_5m**2))
    res_cm5 = (absolute(V_5m[6] - V_5m[0] ) / I_5m[i])
    resistividad_5m = (res_am5 / res_bm5)*res_cm5
    plot (l_5m, resistividad_5m)
    scatter (l_5m, resistividad_5m)
    plt.title('Linea 5 Grupo martes')
    plt.xlabel('l (distancia)')
    plt.ylabel('Resistividad')
# Out:
# 7

# %% [markdown]
# #### Linea 6

# %%
L_5m1 = 50

datos5m1 = np.loadtxt('grupomartes_ultimalinea')
l_5m1 = datos5m1[:,0]
V_5m1 = datos5m1[:,1]
I_5m1 = datos5m1[:,2]
print len(V_5m1)
for i in range (len(I_5m1)):
    res_am51 = pi*(((L_5m1**2)-(l_5m1**2))**2)
    res_bm51 = 2*l_5m1*((L_5m1**2)-(l_5m1**2))
    res_cm51 = (absolute(V_5m1[6] - V_5m1[0] ) / I_5m1[i])
    resistividad_5m1 = (res_am51 / res_bm51)*res_cm51
    plot (l_5m1, resistividad_5m1)
    scatter (l_5m1, resistividad_5m1)
    plt.title('Linea 6 Grupo martes')
    plt.xlabel('l (distancia)')
    plt.ylabel('Resistividad')
# Out:
# 8

# %% [markdown]
# ## Grupo Jara-Pua-Garzon
